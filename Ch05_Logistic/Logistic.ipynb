# %% [markdown]
# # 逻辑回归

# %%
import logRegres
data, label = logRegres.loadDataSet()
logRegres.gradAscent(data,label)
# Out:
# matrix([[ 4.12414349],
#         [ 0.48007329],
#         [-0.6168482 ]])

# %% [markdown]
# 画出数据集和Logistic回归最佳拟合直线的函数

# %%
weights = logRegres.gradAscent(data, label)
logRegres.plotBestFit(weights.getA())

# %% [markdown]
# 画出数据集和Logistic回归最佳拟合直线的函数, 这里的分类器错分了三分之一的样本。

# %%
import numpy
weights = logRegres.stocGradAscent0(numpy.array(data), label)
logRegres.plotBestFit(weights)
